# %%
import matplotlib.pyplot as plt
import numpy as np
recon = np.load('recon.npy')

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(np.abs(recon[:,150,:]))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.4">
